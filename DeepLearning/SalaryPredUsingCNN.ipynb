# %%
""" This script will train a neural network to predict salaries 
based on variables such as occupation, relationship status, the age of the person
and his or her education level. """

# Prepare all the packages this script will need.
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import ModelCheckpoint


# List of all the column names since there was none in the data
columns = ['Age','Workclass','Id','Education','Education Num','Marital Status',
       'Occupation','Relationship','Race','Sex','Capital Gain','Capital Loss',
       'Hours/Week','Country','Salary']

# Load both datasets
df_train = pd.read_csv('C:/Users/Md Jabir Rahman/Desktop/adult-training.csv', names=columns)
df_test = pd.read_csv('C:/Users/Md Jabir Rahman/Desktop/adult-test.csv', header=0, names=columns).loc[1:,:]

# Prepare the salary column for classification
# Salary is 1 if higher than 50k, 0 if lower.
df_train['Salary'] = np.where(df_train['Salary'] == ' >50K',1,0)
df_test['Salary'] = np.where(df_test['Salary'] == ' >50K.',1,0)

# Check the data distribution for salaries. 
# We might need to balance the classes if there's way more of lower or higher salaries.
df_train.Salary.mean()

# Train mean is 0.2408, the ratio of High to low salaries. Approximately 1:3
class_weights = {0: 1,
                1: 3}

# Produce dummy variables for all categories (one-hot encoded, each category is now a column) 
df_train = pd.get_dummies(df_train)
cols = df_train.columns
df_test = pd.get_dummies(df_test)

# Correct for missing variables in test dataset 
# (usually the datasets would be in one dataframe and this wouldn't be necessary)
df_test = df_test.loc[:, cols]
df_test = df_test.fillna(0)

# Drop the salary and Id columns since we dont need those in the training data
X_train = df_train.loc[:, ~((df_train.columns == 'Salary') |
            (df_train.columns == 'Id'))].values
X_test = df_test.loc[:, ~((df_test.columns == 'Salary') |
            (df_test.columns == 'Id'))].values

# Scale the variables, helps train the neural network
scaler = MinMaxScaler()
scaler.fit(X_train)

# Prepare the variables by scaling them, extract the targets into y
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
y_train = df_train['Salary'].values
y_test = df_test['Salary'].values

# A checkpoint allows you to save the ideal weights during training.
# Here we save the weights that give us the best validation accuracy.
checkpoint = ModelCheckpoint("weights.hdf5", monitor='val_acc', 
                             verbose=1, save_best_only=True, 
                             save_weights_only=True, mode='auto', period=1)
                
# Prepare the model

# There's two ways to build models in Keras; 
# Here, we use the Sequential interface, there's also the Function API.
model = Sequential()

# Add a first Dense (fully-connected) layer. 
# You always need to supply the input shape of your data in the first layer.
model.add(Dense(100, input_shape=[X_train.shape[1]], activation='relu'))

# Using dropout can prevent overfitting and should speed up the training.
model.add(Dropout(0.2))

# More layers to allow the network to learn more complex relationships
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.2))

# The last layer is the size of your output. In this case, we have 1 variable,
# the salary (0, 1). It's important to choose the right activation here for 
# the task. Here, this is a classification task, so you need an activation function
# suited for classification. Sigmoid is suited for binary classification and 
# softmax for multiple categorical classification.
# If you're doing regression, then you should do some research to find the 
# right activation function for the task. Relu would work fine most of the time.
model.add(Dense(1, activation='sigmoid'))

# Here I compile and summarize the model. The optimizer I chose is Adam, a 
# common optimizer that works well in general.
# The loss function needs to be chosen carefully. For this classification task, only binary
# crossentropy makes sense.
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# This is where the training starts. The training data is loaded here.
# The batch size specifies how many training examples are loaded in one iteration
# Epochs are the number of training loops. 
# You might need more or less, depending on your problem.
# Here I validate directly on the test data. 
# This can lead to overfitting but is the fastest way to get good results.
model.fit(X_train, y_train, batch_size=5000, epochs=300, verbose=1, 
          validation_data=[X_test,y_test], 
                          callbacks=[checkpoint], class_weight=class_weights)

# Loading the best weights saved during training and recompiling the network.
model.load_weights("weights.hdf5")
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Here I run the model to get the predictions
y_pred = model.predict(X_test)

# To get a confusion matrix you need to bin your values. 
# Here I chose the 0.5 threshold but different ones could suit other purposes.
y_pred_bin = np.where(y_pred >0.5, 1, 0)
matrix = confusion_matrix(y_test, y_pred_bin)

print("Precision: Salaries below 50K", round(matrix[0,0] / (matrix[0,0] + matrix[0,1])),2)
print("Precision: Salaries higher than 50K", round(matrix[1,1] / (matrix[1,1] + matrix[1,0])),2)
# Out:
# C:\Users\Md Jabir Rahman\Anaconda3\envs\tensorflow_env\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 100)               10800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________
# Train on 32561 samples, validate on 16280 samples
# Epoch 1/300
# 32561/32561 [==============================] - 5s 139us/step - loss: 0.9765 - acc: 0.5626 - val_loss: 0.6198 - val_acc: 0.7029
#
# Epoch 00001: val_acc improved from -inf to 0.70295, saving model to weights.hdf5
# Epoch 2/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.8478 - acc: 0.7124 - val_loss: 0.5318 - val_acc: 0.7246
#
# Epoch 00002: val_acc improved from 0.70295 to 0.72463, saving model to weights.hdf5
# Epoch 3/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.7507 - acc: 0.7404 - val_loss: 0.4618 - val_acc: 0.7657
#
# Epoch 00003: val_acc improved from 0.72463 to 0.76566, saving model to weights.hdf5
# Epoch 4/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.7133 - acc: 0.7645 - val_loss: 0.4585 - val_acc: 0.7817
#
# Epoch 00004: val_acc improved from 0.76566 to 0.78170, saving model to weights.hdf5
# Epoch 5/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.6835 - acc: 0.7742 - val_loss: 0.4401 - val_acc: 0.7933
#
# Epoch 00005: val_acc improved from 0.78170 to 0.79330, saving model to weights.hdf5
# Epoch 6/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.6638 - acc: 0.7791 - val_loss: 0.4471 - val_acc: 0.7732
#
# Epoch 00006: val_acc did not improve from 0.79330
# Epoch 7/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.6492 - acc: 0.7749 - val_loss: 0.4190 - val_acc: 0.7849
#
# Epoch 00007: val_acc did not improve from 0.79330
# Epoch 8/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.6420 - acc: 0.7819 - val_loss: 0.4451 - val_acc: 0.7675
#
# Epoch 00008: val_acc did not improve from 0.79330
# Epoch 9/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6342 - acc: 0.7809 - val_loss: 0.4195 - val_acc: 0.7810
#
# Epoch 00009: val_acc did not improve from 0.79330
# Epoch 10/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6333 - acc: 0.7757 - val_loss: 0.4207 - val_acc: 0.7808
#
# Epoch 00010: val_acc did not improve from 0.79330
# Epoch 11/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.6257 - acc: 0.7866 - val_loss: 0.4307 - val_acc: 0.7751
#
# Epoch 00011: val_acc did not improve from 0.79330
# Epoch 12/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6200 - acc: 0.7801 - val_loss: 0.4049 - val_acc: 0.7932
#
# Epoch 00012: val_acc did not improve from 0.79330
# Epoch 13/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.6185 - acc: 0.7908 - val_loss: 0.4279 - val_acc: 0.7798
#
# Epoch 00013: val_acc did not improve from 0.79330
# Epoch 14/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6129 - acc: 0.7893 - val_loss: 0.4051 - val_acc: 0.7936
#
# Epoch 00014: val_acc improved from 0.79330 to 0.79361, saving model to weights.hdf5
# Epoch 15/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.6118 - acc: 0.7875 - val_loss: 0.4127 - val_acc: 0.7884
#
# Epoch 00015: val_acc did not improve from 0.79361
# Epoch 16/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.6077 - acc: 0.7919 - val_loss: 0.4093 - val_acc: 0.7905
#
# Epoch 00016: val_acc did not improve from 0.79361
# Epoch 17/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6071 - acc: 0.7880 - val_loss: 0.4106 - val_acc: 0.7912
#
# Epoch 00017: val_acc did not improve from 0.79361
# Epoch 18/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.6004 - acc: 0.7950 - val_loss: 0.4044 - val_acc: 0.7947
#
# Epoch 00018: val_acc improved from 0.79361 to 0.79472, saving model to weights.hdf5
# Epoch 19/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5967 - acc: 0.7924 - val_loss: 0.4009 - val_acc: 0.7978
#
# Epoch 00019: val_acc improved from 0.79472 to 0.79779, saving model to weights.hdf5
# Epoch 20/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.5961 - acc: 0.7952 - val_loss: 0.4111 - val_acc: 0.7886
#
# Epoch 00020: val_acc did not improve from 0.79779
# Epoch 21/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5939 - acc: 0.7970 - val_loss: 0.4048 - val_acc: 0.7931
#
# Epoch 00021: val_acc did not improve from 0.79779
# Epoch 22/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.5939 - acc: 0.7874 - val_loss: 0.3860 - val_acc: 0.8041
#
# Epoch 00022: val_acc improved from 0.79779 to 0.80405, saving model to weights.hdf5
# Epoch 23/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5893 - acc: 0.8000 - val_loss: 0.4187 - val_acc: 0.7830
#
# Epoch 00023: val_acc did not improve from 0.80405
# Epoch 24/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5879 - acc: 0.7970 - val_loss: 0.3973 - val_acc: 0.7990
#
# Epoch 00024: val_acc did not improve from 0.80405
# Epoch 25/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5842 - acc: 0.7994 - val_loss: 0.4021 - val_acc: 0.7941
#
# Epoch 00025: val_acc did not improve from 0.80405
# Epoch 26/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.5825 - acc: 0.8001 - val_loss: 0.3998 - val_acc: 0.7940
#
# Epoch 00026: val_acc did not improve from 0.80405
# Epoch 27/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5773 - acc: 0.8026 - val_loss: 0.4011 - val_acc: 0.7932
#
# Epoch 00027: val_acc did not improve from 0.80405
# Epoch 28/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.5786 - acc: 0.8002 - val_loss: 0.3950 - val_acc: 0.7980
#
# Epoch 00028: val_acc did not improve from 0.80405
# Epoch 29/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.5754 - acc: 0.8007 - val_loss: 0.3952 - val_acc: 0.7976
#
# Epoch 00029: val_acc did not improve from 0.80405
# Epoch 30/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5751 - acc: 0.8014 - val_loss: 0.3914 - val_acc: 0.8007
#
# Epoch 00030: val_acc did not improve from 0.80405
# Epoch 31/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5719 - acc: 0.8051 - val_loss: 0.4011 - val_acc: 0.7953
#
# Epoch 00031: val_acc did not improve from 0.80405
# Epoch 32/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5684 - acc: 0.8036 - val_loss: 0.3933 - val_acc: 0.7982
#
# Epoch 00032: val_acc did not improve from 0.80405
# Epoch 33/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.5666 - acc: 0.8016 - val_loss: 0.3892 - val_acc: 0.8028
#
# Epoch 00033: val_acc did not improve from 0.80405
# Epoch 34/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5668 - acc: 0.8053 - val_loss: 0.4112 - val_acc: 0.7858
#
# Epoch 00034: val_acc did not improve from 0.80405
# Epoch 35/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.5662 - acc: 0.8022 - val_loss: 0.3808 - val_acc: 0.8052
#
# Epoch 00035: val_acc improved from 0.80405 to 0.80516, saving model to weights.hdf5
# Epoch 36/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5639 - acc: 0.8025 - val_loss: 0.3861 - val_acc: 0.8041
#
# Epoch 00036: val_acc did not improve from 0.80516
# Epoch 37/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.5623 - acc: 0.8086 - val_loss: 0.4039 - val_acc: 0.7919
#
# Epoch 00037: val_acc did not improve from 0.80516
# Epoch 38/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5566 - acc: 0.8072 - val_loss: 0.3946 - val_acc: 0.7979
#
# Epoch 00038: val_acc did not improve from 0.80516
# Epoch 39/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5532 - acc: 0.8055 - val_loss: 0.3822 - val_acc: 0.8067
#
# Epoch 00039: val_acc improved from 0.80516 to 0.80670, saving model to weights.hdf5
# Epoch 40/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5558 - acc: 0.8046 - val_loss: 0.3833 - val_acc: 0.8036
#
# Epoch 00040: val_acc did not improve from 0.80670
# Epoch 41/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5523 - acc: 0.8063 - val_loss: 0.3825 - val_acc: 0.8047
#
# Epoch 00041: val_acc did not improve from 0.80670
# Epoch 42/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5503 - acc: 0.8105 - val_loss: 0.4071 - val_acc: 0.7910
#
# Epoch 00042: val_acc did not improve from 0.80670
# Epoch 43/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5496 - acc: 0.8099 - val_loss: 0.3896 - val_acc: 0.8016
#
# Epoch 00043: val_acc did not improve from 0.80670
# Epoch 44/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5455 - acc: 0.8065 - val_loss: 0.3846 - val_acc: 0.8046
#
# Epoch 00044: val_acc did not improve from 0.80670
# Epoch 45/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5445 - acc: 0.8101 - val_loss: 0.3913 - val_acc: 0.8012
#
# Epoch 00045: val_acc did not improve from 0.80670
# Epoch 46/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5446 - acc: 0.8108 - val_loss: 0.3909 - val_acc: 0.8002
#
# Epoch 00046: val_acc did not improve from 0.80670
# Epoch 47/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.5412 - acc: 0.8111 - val_loss: 0.3944 - val_acc: 0.7971
#
# Epoch 00047: val_acc did not improve from 0.80670
# Epoch 48/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.5438 - acc: 0.8118 - val_loss: 0.4000 - val_acc: 0.7943
#
# Epoch 00048: val_acc did not improve from 0.80670
# Epoch 49/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5401 - acc: 0.8082 - val_loss: 0.3808 - val_acc: 0.8047
#
# Epoch 00049: val_acc did not improve from 0.80670
# Epoch 50/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.5392 - acc: 0.8111 - val_loss: 0.3824 - val_acc: 0.8054
#
# Epoch 00050: val_acc did not improve from 0.80670
# Epoch 51/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5367 - acc: 0.8134 - val_loss: 0.3865 - val_acc: 0.8039
#
# Epoch 00051: val_acc did not improve from 0.80670
# Epoch 52/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.5347 - acc: 0.8146 - val_loss: 0.3918 - val_acc: 0.7982
#
# Epoch 00052: val_acc did not improve from 0.80670
# Epoch 53/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5335 - acc: 0.8133 - val_loss: 0.3856 - val_acc: 0.8012
#
# Epoch 00053: val_acc did not improve from 0.80670
# Epoch 54/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5311 - acc: 0.8152 - val_loss: 0.3843 - val_acc: 0.8053
#
# Epoch 00054: val_acc did not improve from 0.80670
# Epoch 55/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5310 - acc: 0.8134 - val_loss: 0.3803 - val_acc: 0.8053
#
# Epoch 00055: val_acc did not improve from 0.80670
# Epoch 56/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5295 - acc: 0.8150 - val_loss: 0.3926 - val_acc: 0.7981
#
# Epoch 00056: val_acc did not improve from 0.80670
# Epoch 57/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5289 - acc: 0.8159 - val_loss: 0.3907 - val_acc: 0.8006
#
# Epoch 00057: val_acc did not improve from 0.80670
# Epoch 58/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5261 - acc: 0.8154 - val_loss: 0.3835 - val_acc: 0.8041
#
# Epoch 00058: val_acc did not improve from 0.80670
# Epoch 59/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5256 - acc: 0.8158 - val_loss: 0.3739 - val_acc: 0.8109
#
# Epoch 00059: val_acc improved from 0.80670 to 0.81093, saving model to weights.hdf5
# Epoch 60/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5228 - acc: 0.8171 - val_loss: 0.3844 - val_acc: 0.8037
#
# Epoch 00060: val_acc did not improve from 0.81093
# Epoch 61/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5250 - acc: 0.8143 - val_loss: 0.3733 - val_acc: 0.8092
#
# Epoch 00061: val_acc did not improve from 0.81093
# Epoch 62/300
# 32561/32561 [==============================] - 1s 37us/step - loss: 0.5226 - acc: 0.8157 - val_loss: 0.3802 - val_acc: 0.8070
#
# Epoch 00062: val_acc did not improve from 0.81093
# Epoch 63/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.5199 - acc: 0.8191 - val_loss: 0.3816 - val_acc: 0.8061
#
# Epoch 00063: val_acc did not improve from 0.81093
# Epoch 64/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.5196 - acc: 0.8163 - val_loss: 0.3800 - val_acc: 0.8069
#
# Epoch 00064: val_acc did not improve from 0.81093
# Epoch 65/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5169 - acc: 0.8174 - val_loss: 0.3806 - val_acc: 0.8058
#
# Epoch 00065: val_acc did not improve from 0.81093
# Epoch 66/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.5167 - acc: 0.8190 - val_loss: 0.3931 - val_acc: 0.7985
#
# Epoch 00066: val_acc did not improve from 0.81093
# Epoch 67/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.5170 - acc: 0.8238 - val_loss: 0.4076 - val_acc: 0.7897
#
# Epoch 00067: val_acc did not improve from 0.81093
# Epoch 68/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5138 - acc: 0.8174 - val_loss: 0.3832 - val_acc: 0.8068
#
# Epoch 00068: val_acc did not improve from 0.81093
# Epoch 69/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5136 - acc: 0.8164 - val_loss: 0.3720 - val_acc: 0.8120
#
# Epoch 00069: val_acc improved from 0.81093 to 0.81204, saving model to weights.hdf5
# Epoch 70/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5135 - acc: 0.8196 - val_loss: 0.3802 - val_acc: 0.8055
#
# Epoch 00070: val_acc did not improve from 0.81204
# Epoch 71/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.5091 - acc: 0.8215 - val_loss: 0.3824 - val_acc: 0.8067
#
# Epoch 00071: val_acc did not improve from 0.81204
# Epoch 72/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.5105 - acc: 0.8218 - val_loss: 0.3832 - val_acc: 0.8049
#
# Epoch 00072: val_acc did not improve from 0.81204
# Epoch 73/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.5083 - acc: 0.8237 - val_loss: 0.4044 - val_acc: 0.7918
#
# Epoch 00073: val_acc did not improve from 0.81204
# Epoch 74/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5089 - acc: 0.8229 - val_loss: 0.3926 - val_acc: 0.8010
#
# Epoch 00074: val_acc did not improve from 0.81204
# Epoch 75/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5098 - acc: 0.8152 - val_loss: 0.3630 - val_acc: 0.8203
#
# Epoch 00075: val_acc improved from 0.81204 to 0.82033, saving model to weights.hdf5
# Epoch 76/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.5039 - acc: 0.8231 - val_loss: 0.3867 - val_acc: 0.8063
#
# Epoch 00076: val_acc did not improve from 0.82033
# Epoch 77/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.5028 - acc: 0.8256 - val_loss: 0.3852 - val_acc: 0.8047
#
# Epoch 00077: val_acc did not improve from 0.82033
# Epoch 78/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.5026 - acc: 0.8245 - val_loss: 0.3921 - val_acc: 0.8018
#
# Epoch 00078: val_acc did not improve from 0.82033
# Epoch 79/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5043 - acc: 0.8248 - val_loss: 0.3917 - val_acc: 0.8016
#
# Epoch 00079: val_acc did not improve from 0.82033
# Epoch 80/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5025 - acc: 0.8257 - val_loss: 0.3881 - val_acc: 0.8041
#
# Epoch 00080: val_acc did not improve from 0.82033
# Epoch 81/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5001 - acc: 0.8237 - val_loss: 0.3767 - val_acc: 0.8136
#
# Epoch 00081: val_acc did not improve from 0.82033
# Epoch 82/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.4941 - acc: 0.8258 - val_loss: 0.3826 - val_acc: 0.8092
#
# Epoch 00082: val_acc did not improve from 0.82033
# Epoch 83/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.5005 - acc: 0.8239 - val_loss: 0.3828 - val_acc: 0.8093
#
# Epoch 00083: val_acc did not improve from 0.82033
# Epoch 84/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4971 - acc: 0.8279 - val_loss: 0.3853 - val_acc: 0.8093
#
# Epoch 00084: val_acc did not improve from 0.82033
# Epoch 85/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4922 - acc: 0.8268 - val_loss: 0.3860 - val_acc: 0.8075
#
# Epoch 00085: val_acc did not improve from 0.82033
# Epoch 86/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4939 - acc: 0.8246 - val_loss: 0.3771 - val_acc: 0.8131
#
# Epoch 00086: val_acc did not improve from 0.82033
# Epoch 87/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4911 - acc: 0.8256 - val_loss: 0.3865 - val_acc: 0.8084
#
# Epoch 00087: val_acc did not improve from 0.82033
# Epoch 88/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4927 - acc: 0.8265 - val_loss: 0.3869 - val_acc: 0.8084
#
# Epoch 00088: val_acc did not improve from 0.82033
# Epoch 89/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4913 - acc: 0.8268 - val_loss: 0.3830 - val_acc: 0.8100
#
# Epoch 00089: val_acc did not improve from 0.82033
# Epoch 90/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4898 - acc: 0.8303 - val_loss: 0.3973 - val_acc: 0.8023
#
# Epoch 00090: val_acc did not improve from 0.82033
# Epoch 91/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4895 - acc: 0.8314 - val_loss: 0.4043 - val_acc: 0.7981
#
# Epoch 00091: val_acc did not improve from 0.82033
# Epoch 92/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4899 - acc: 0.8281 - val_loss: 0.3894 - val_acc: 0.8061
#
# Epoch 00092: val_acc did not improve from 0.82033
# Epoch 93/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4897 - acc: 0.8284 - val_loss: 0.3819 - val_acc: 0.8114
#
# Epoch 00093: val_acc did not improve from 0.82033
# Epoch 94/300
# 32561/32561 [==============================] - 1s 37us/step - loss: 0.4882 - acc: 0.8254 - val_loss: 0.3705 - val_acc: 0.8190
#
# Epoch 00094: val_acc did not improve from 0.82033
# Epoch 95/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4896 - acc: 0.8260 - val_loss: 0.3872 - val_acc: 0.8088
#
# Epoch 00095: val_acc did not improve from 0.82033
# Epoch 96/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4872 - acc: 0.8315 - val_loss: 0.3947 - val_acc: 0.8057
#
# Epoch 00096: val_acc did not improve from 0.82033
# Epoch 97/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4865 - acc: 0.8303 - val_loss: 0.3897 - val_acc: 0.8083
#
# Epoch 00097: val_acc did not improve from 0.82033
# Epoch 98/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4868 - acc: 0.8287 - val_loss: 0.3916 - val_acc: 0.8062
#
# Epoch 00098: val_acc did not improve from 0.82033
# Epoch 99/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4828 - acc: 0.8303 - val_loss: 0.3854 - val_acc: 0.8101
#
# Epoch 00099: val_acc did not improve from 0.82033
# Epoch 100/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4854 - acc: 0.8273 - val_loss: 0.3728 - val_acc: 0.8206
#
# Epoch 00100: val_acc improved from 0.82033 to 0.82058, saving model to weights.hdf5
# Epoch 101/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4819 - acc: 0.8329 - val_loss: 0.3849 - val_acc: 0.8100
#
# Epoch 00101: val_acc did not improve from 0.82058
# Epoch 102/300
# 32561/32561 [==============================] - 1s 40us/step - loss: 0.4840 - acc: 0.8284 - val_loss: 0.3839 - val_acc: 0.8123
#
# Epoch 00102: val_acc did not improve from 0.82058
# Epoch 103/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4838 - acc: 0.8291 - val_loss: 0.3935 - val_acc: 0.8044
#
# Epoch 00103: val_acc did not improve from 0.82058
# Epoch 104/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4803 - acc: 0.8305 - val_loss: 0.3793 - val_acc: 0.8160
#
# Epoch 00104: val_acc did not improve from 0.82058
# Epoch 105/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4799 - acc: 0.8326 - val_loss: 0.3858 - val_acc: 0.8145
#
# Epoch 00105: val_acc did not improve from 0.82058
# Epoch 106/300
# 32561/32561 [==============================] - 1s 37us/step - loss: 0.4786 - acc: 0.8363 - val_loss: 0.3926 - val_acc: 0.8080
#
# Epoch 00106: val_acc did not improve from 0.82058
# Epoch 107/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4791 - acc: 0.8317 - val_loss: 0.3965 - val_acc: 0.8062
#
# Epoch 00107: val_acc did not improve from 0.82058
# Epoch 108/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4752 - acc: 0.8326 - val_loss: 0.3840 - val_acc: 0.8156
#
# Epoch 00108: val_acc did not improve from 0.82058
# Epoch 109/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4802 - acc: 0.8321 - val_loss: 0.3881 - val_acc: 0.8124
#
# Epoch 00109: val_acc did not improve from 0.82058
# Epoch 110/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4792 - acc: 0.8327 - val_loss: 0.3888 - val_acc: 0.8101
#
# Epoch 00110: val_acc did not improve from 0.82058
# Epoch 111/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4744 - acc: 0.8335 - val_loss: 0.3921 - val_acc: 0.8080
#
# Epoch 00111: val_acc did not improve from 0.82058
# Epoch 112/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4773 - acc: 0.8308 - val_loss: 0.3774 - val_acc: 0.8211
#
# Epoch 00112: val_acc improved from 0.82058 to 0.82107, saving model to weights.hdf5
# Epoch 113/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4749 - acc: 0.8343 - val_loss: 0.3904 - val_acc: 0.8110
#
# Epoch 00113: val_acc did not improve from 0.82107
# Epoch 114/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4731 - acc: 0.8374 - val_loss: 0.4106 - val_acc: 0.7988
#
# Epoch 00114: val_acc did not improve from 0.82107
# Epoch 115/300
# 32561/32561 [==============================] - 1s 40us/step - loss: 0.4755 - acc: 0.8334 - val_loss: 0.3916 - val_acc: 0.8129
#
# Epoch 00115: val_acc did not improve from 0.82107
# Epoch 116/300
# 32561/32561 [==============================] - ETA: 0s - loss: 0.4707 - acc: 0.832 - 1s 35us/step - loss: 0.4729 - acc: 0.8321 - val_loss: 0.3863 - val_acc: 0.8150
#
# Epoch 00116: val_acc did not improve from 0.82107
# Epoch 117/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4739 - acc: 0.8335 - val_loss: 0.3844 - val_acc: 0.8155
#
# Epoch 00117: val_acc did not improve from 0.82107
# Epoch 118/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4722 - acc: 0.8359 - val_loss: 0.3873 - val_acc: 0.8155
#
# Epoch 00118: val_acc did not improve from 0.82107
# Epoch 119/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4706 - acc: 0.8373 - val_loss: 0.3989 - val_acc: 0.8084
#
# Epoch 00119: val_acc did not improve from 0.82107
# Epoch 120/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.4704 - acc: 0.8383 - val_loss: 0.4046 - val_acc: 0.8034
#
# Epoch 00120: val_acc did not improve from 0.82107
# Epoch 121/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4698 - acc: 0.8326 - val_loss: 0.3976 - val_acc: 0.8092
#
# Epoch 00121: val_acc did not improve from 0.82107
# Epoch 122/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4722 - acc: 0.8335 - val_loss: 0.3988 - val_acc: 0.8088
#
# Epoch 00122: val_acc did not improve from 0.82107
# Epoch 123/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4701 - acc: 0.8347 - val_loss: 0.3944 - val_acc: 0.8118
#
# Epoch 00123: val_acc did not improve from 0.82107
# Epoch 124/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4683 - acc: 0.8342 - val_loss: 0.3895 - val_acc: 0.8157
#
# Epoch 00124: val_acc did not improve from 0.82107
# Epoch 125/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4686 - acc: 0.8341 - val_loss: 0.3882 - val_acc: 0.8165
#
# Epoch 00125: val_acc did not improve from 0.82107
# Epoch 126/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.4689 - acc: 0.8358 - val_loss: 0.3950 - val_acc: 0.8120
#
# Epoch 00126: val_acc did not improve from 0.82107
# Epoch 127/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4676 - acc: 0.8379 - val_loss: 0.4001 - val_acc: 0.8092
#
# Epoch 00127: val_acc did not improve from 0.82107
# Epoch 128/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4657 - acc: 0.8370 - val_loss: 0.3925 - val_acc: 0.8117
#
# Epoch 00128: val_acc did not improve from 0.82107
# Epoch 129/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4667 - acc: 0.8368 - val_loss: 0.3950 - val_acc: 0.8146
#
# Epoch 00129: val_acc did not improve from 0.82107
# Epoch 130/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4667 - acc: 0.8388 - val_loss: 0.4016 - val_acc: 0.8087
#
# Epoch 00130: val_acc did not improve from 0.82107
# Epoch 131/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4673 - acc: 0.8358 - val_loss: 0.4007 - val_acc: 0.8069
#
# Epoch 00131: val_acc did not improve from 0.82107
# Epoch 132/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4662 - acc: 0.8367 - val_loss: 0.3983 - val_acc: 0.8131
#
# Epoch 00132: val_acc did not improve from 0.82107
# Epoch 133/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4671 - acc: 0.8360 - val_loss: 0.3960 - val_acc: 0.8125
#
# Epoch 00133: val_acc did not improve from 0.82107
# Epoch 134/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4661 - acc: 0.8382 - val_loss: 0.3947 - val_acc: 0.8138
#
# Epoch 00134: val_acc did not improve from 0.82107
# Epoch 135/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4614 - acc: 0.8373 - val_loss: 0.3960 - val_acc: 0.8170
#
# Epoch 00135: val_acc did not improve from 0.82107
# Epoch 136/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4619 - acc: 0.8373 - val_loss: 0.3983 - val_acc: 0.8119
#
# Epoch 00136: val_acc did not improve from 0.82107
# Epoch 137/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4639 - acc: 0.8385 - val_loss: 0.4029 - val_acc: 0.8100
#
# Epoch 00137: val_acc did not improve from 0.82107
# Epoch 138/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4650 - acc: 0.8376 - val_loss: 0.3977 - val_acc: 0.8122
#
# Epoch 00138: val_acc did not improve from 0.82107
# Epoch 139/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4628 - acc: 0.8365 - val_loss: 0.3915 - val_acc: 0.8198
#
# Epoch 00139: val_acc did not improve from 0.82107
# Epoch 140/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4620 - acc: 0.8362 - val_loss: 0.3945 - val_acc: 0.8157
#
# Epoch 00140: val_acc did not improve from 0.82107
# Epoch 141/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4611 - acc: 0.8404 - val_loss: 0.4070 - val_acc: 0.8078
#
# Epoch 00141: val_acc did not improve from 0.82107
# Epoch 142/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4606 - acc: 0.8372 - val_loss: 0.3949 - val_acc: 0.8171
#
# Epoch 00142: val_acc did not improve from 0.82107
# Epoch 143/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4622 - acc: 0.8381 - val_loss: 0.4072 - val_acc: 0.8082
#
# Epoch 00143: val_acc did not improve from 0.82107
# Epoch 144/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4612 - acc: 0.8405 - val_loss: 0.4067 - val_acc: 0.8077
#
# Epoch 00144: val_acc did not improve from 0.82107
# Epoch 145/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4625 - acc: 0.8378 - val_loss: 0.4061 - val_acc: 0.8088
#
# Epoch 00145: val_acc did not improve from 0.82107
# Epoch 146/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4613 - acc: 0.8348 - val_loss: 0.3931 - val_acc: 0.8181
#
# Epoch 00146: val_acc did not improve from 0.82107
# Epoch 147/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4609 - acc: 0.8393 - val_loss: 0.3951 - val_acc: 0.8144
#
# Epoch 00147: val_acc did not improve from 0.82107
# Epoch 148/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4592 - acc: 0.8414 - val_loss: 0.4056 - val_acc: 0.8053
#
# Epoch 00148: val_acc did not improve from 0.82107
# Epoch 149/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4570 - acc: 0.8383 - val_loss: 0.3973 - val_acc: 0.8166
#
# Epoch 00149: val_acc did not improve from 0.82107
# Epoch 150/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4575 - acc: 0.8378 - val_loss: 0.3952 - val_acc: 0.8178
#
# Epoch 00150: val_acc did not improve from 0.82107
# Epoch 151/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4560 - acc: 0.8422 - val_loss: 0.4066 - val_acc: 0.8111
#
# Epoch 00151: val_acc did not improve from 0.82107
# Epoch 152/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4544 - acc: 0.8423 - val_loss: 0.4070 - val_acc: 0.8077
#
# Epoch 00152: val_acc did not improve from 0.82107
# Epoch 153/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.4544 - acc: 0.8424 - val_loss: 0.4077 - val_acc: 0.8074
#
# Epoch 00153: val_acc did not improve from 0.82107
# Epoch 154/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4547 - acc: 0.8387 - val_loss: 0.4010 - val_acc: 0.8146
#
# Epoch 00154: val_acc did not improve from 0.82107
# Epoch 155/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4549 - acc: 0.8399 - val_loss: 0.3996 - val_acc: 0.8175
#
# Epoch 00155: val_acc did not improve from 0.82107
# Epoch 156/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4555 - acc: 0.8385 - val_loss: 0.3976 - val_acc: 0.8180
#
# Epoch 00156: val_acc did not improve from 0.82107
# Epoch 157/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4579 - acc: 0.8405 - val_loss: 0.4030 - val_acc: 0.8142
#
# Epoch 00157: val_acc did not improve from 0.82107
# Epoch 158/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4554 - acc: 0.8429 - val_loss: 0.4177 - val_acc: 0.8025
#
# Epoch 00158: val_acc did not improve from 0.82107
# Epoch 159/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4533 - acc: 0.8422 - val_loss: 0.4076 - val_acc: 0.8096
#
# Epoch 00159: val_acc did not improve from 0.82107
# Epoch 160/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4520 - acc: 0.8388 - val_loss: 0.3996 - val_acc: 0.8190
#
# Epoch 00160: val_acc did not improve from 0.82107
# Epoch 161/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4557 - acc: 0.8425 - val_loss: 0.3993 - val_acc: 0.8144
#
# Epoch 00161: val_acc did not improve from 0.82107
# Epoch 162/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4514 - acc: 0.8427 - val_loss: 0.4054 - val_acc: 0.8143
#
# Epoch 00162: val_acc did not improve from 0.82107
# Epoch 163/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4532 - acc: 0.8422 - val_loss: 0.4003 - val_acc: 0.8184
#
# Epoch 00163: val_acc did not improve from 0.82107
# Epoch 164/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4486 - acc: 0.8443 - val_loss: 0.4020 - val_acc: 0.8179
#
# Epoch 00164: val_acc did not improve from 0.82107
# Epoch 165/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4523 - acc: 0.8424 - val_loss: 0.4076 - val_acc: 0.8115
#
# Epoch 00165: val_acc did not improve from 0.82107
# Epoch 166/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4484 - acc: 0.8441 - val_loss: 0.4019 - val_acc: 0.8171
#
# Epoch 00166: val_acc did not improve from 0.82107
# Epoch 167/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4519 - acc: 0.8412 - val_loss: 0.4104 - val_acc: 0.8130
#
# Epoch 00167: val_acc did not improve from 0.82107
# Epoch 168/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4492 - acc: 0.8467 - val_loss: 0.4210 - val_acc: 0.8048
#
# Epoch 00168: val_acc did not improve from 0.82107
# Epoch 169/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4491 - acc: 0.8400 - val_loss: 0.4091 - val_acc: 0.8139
#
# Epoch 00169: val_acc did not improve from 0.82107
# Epoch 170/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4506 - acc: 0.8401 - val_loss: 0.4027 - val_acc: 0.8185
#
# Epoch 00170: val_acc did not improve from 0.82107
# Epoch 171/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4484 - acc: 0.8404 - val_loss: 0.4085 - val_acc: 0.8142
#
# Epoch 00171: val_acc did not improve from 0.82107
# Epoch 172/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4495 - acc: 0.8415 - val_loss: 0.4104 - val_acc: 0.8140
#
# Epoch 00172: val_acc did not improve from 0.82107
# Epoch 173/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4482 - acc: 0.8454 - val_loss: 0.4159 - val_acc: 0.8088
#
# Epoch 00173: val_acc did not improve from 0.82107
# Epoch 174/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4463 - acc: 0.8417 - val_loss: 0.4013 - val_acc: 0.8231
#
# Epoch 00174: val_acc improved from 0.82107 to 0.82310, saving model to weights.hdf5
# Epoch 175/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4502 - acc: 0.8410 - val_loss: 0.4170 - val_acc: 0.8096
#
# Epoch 00175: val_acc did not improve from 0.82310
# Epoch 176/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4453 - acc: 0.8421 - val_loss: 0.4069 - val_acc: 0.8175
#
# Epoch 00176: val_acc did not improve from 0.82310
# Epoch 177/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4476 - acc: 0.8426 - val_loss: 0.4127 - val_acc: 0.8141
#
# Epoch 00177: val_acc did not improve from 0.82310
# Epoch 178/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4484 - acc: 0.8433 - val_loss: 0.4269 - val_acc: 0.8030
#
# Epoch 00178: val_acc did not improve from 0.82310
# Epoch 179/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4463 - acc: 0.8448 - val_loss: 0.4190 - val_acc: 0.8067
#
# Epoch 00179: val_acc did not improve from 0.82310
# Epoch 180/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4467 - acc: 0.8384 - val_loss: 0.4005 - val_acc: 0.8248
#
# Epoch 00180: val_acc improved from 0.82310 to 0.82475, saving model to weights.hdf5
# Epoch 181/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4471 - acc: 0.8438 - val_loss: 0.4133 - val_acc: 0.8123
#
# Epoch 00181: val_acc did not improve from 0.82475
# Epoch 182/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4441 - acc: 0.8421 - val_loss: 0.4129 - val_acc: 0.8136
#
# Epoch 00182: val_acc did not improve from 0.82475
# Epoch 183/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4421 - acc: 0.8459 - val_loss: 0.4144 - val_acc: 0.8140
#
# Epoch 00183: val_acc did not improve from 0.82475
# Epoch 184/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4469 - acc: 0.8438 - val_loss: 0.4166 - val_acc: 0.8123
#
# Epoch 00184: val_acc did not improve from 0.82475
# Epoch 185/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4452 - acc: 0.8455 - val_loss: 0.4133 - val_acc: 0.8153
#
# Epoch 00185: val_acc did not improve from 0.82475
# Epoch 186/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4442 - acc: 0.8464 - val_loss: 0.4132 - val_acc: 0.8163
#
# Epoch 00186: val_acc did not improve from 0.82475
# Epoch 187/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4447 - acc: 0.8458 - val_loss: 0.4129 - val_acc: 0.8147
#
# Epoch 00187: val_acc did not improve from 0.82475
# Epoch 188/300
# 32561/32561 [==============================] - 1s 38us/step - loss: 0.4456 - acc: 0.8407 - val_loss: 0.4070 - val_acc: 0.8200
#
# Epoch 00188: val_acc did not improve from 0.82475
# Epoch 189/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4398 - acc: 0.8465 - val_loss: 0.4241 - val_acc: 0.8093
#
# Epoch 00189: val_acc did not improve from 0.82475
# Epoch 190/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4445 - acc: 0.8468 - val_loss: 0.4181 - val_acc: 0.8114
#
# Epoch 00190: val_acc did not improve from 0.82475
# Epoch 191/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4417 - acc: 0.8425 - val_loss: 0.4090 - val_acc: 0.8191
#
# Epoch 00191: val_acc did not improve from 0.82475
# Epoch 192/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4388 - acc: 0.8453 - val_loss: 0.4182 - val_acc: 0.8158
#
# Epoch 00192: val_acc did not improve from 0.82475
# Epoch 193/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4430 - acc: 0.8447 - val_loss: 0.4108 - val_acc: 0.8192
#
# Epoch 00193: val_acc did not improve from 0.82475
# Epoch 194/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4419 - acc: 0.8447 - val_loss: 0.4152 - val_acc: 0.8146
#
# Epoch 00194: val_acc did not improve from 0.82475
# Epoch 195/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4406 - acc: 0.8483 - val_loss: 0.4202 - val_acc: 0.8138
#
# Epoch 00195: val_acc did not improve from 0.82475
# Epoch 196/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4415 - acc: 0.8444 - val_loss: 0.4100 - val_acc: 0.8198
#
# Epoch 00196: val_acc did not improve from 0.82475
# Epoch 197/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4408 - acc: 0.8444 - val_loss: 0.4191 - val_acc: 0.8143
#
# Epoch 00197: val_acc did not improve from 0.82475
# Epoch 198/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4394 - acc: 0.8478 - val_loss: 0.4187 - val_acc: 0.8157
#
# Epoch 00198: val_acc did not improve from 0.82475
# Epoch 199/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4385 - acc: 0.8501 - val_loss: 0.4207 - val_acc: 0.8108
#
# Epoch 00199: val_acc did not improve from 0.82475
# Epoch 200/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4376 - acc: 0.8459 - val_loss: 0.4212 - val_acc: 0.8127
#
# Epoch 00200: val_acc did not improve from 0.82475
# Epoch 201/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4364 - acc: 0.8456 - val_loss: 0.4163 - val_acc: 0.8147
#
# Epoch 00201: val_acc did not improve from 0.82475
# Epoch 202/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4373 - acc: 0.8480 - val_loss: 0.4230 - val_acc: 0.8145
#
# Epoch 00202: val_acc did not improve from 0.82475
# Epoch 203/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4384 - acc: 0.8460 - val_loss: 0.4176 - val_acc: 0.8179
#
# Epoch 00203: val_acc did not improve from 0.82475
# Epoch 204/300
# 32561/32561 [==============================] - 1s 37us/step - loss: 0.4385 - acc: 0.8452 - val_loss: 0.4172 - val_acc: 0.8173
#
# Epoch 00204: val_acc did not improve from 0.82475
# Epoch 205/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4393 - acc: 0.8432 - val_loss: 0.4114 - val_acc: 0.8225
#
# Epoch 00205: val_acc did not improve from 0.82475
# Epoch 206/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4394 - acc: 0.8470 - val_loss: 0.4188 - val_acc: 0.8157
#
# Epoch 00206: val_acc did not improve from 0.82475
# Epoch 207/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4337 - acc: 0.8493 - val_loss: 0.4213 - val_acc: 0.8157
#
# Epoch 00207: val_acc did not improve from 0.82475
# Epoch 208/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4375 - acc: 0.8468 - val_loss: 0.4183 - val_acc: 0.8161
#
# Epoch 00208: val_acc did not improve from 0.82475
# Epoch 209/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4352 - acc: 0.8486 - val_loss: 0.4214 - val_acc: 0.8138
#
# Epoch 00209: val_acc did not improve from 0.82475
# Epoch 210/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4366 - acc: 0.8437 - val_loss: 0.4146 - val_acc: 0.8190
#
# Epoch 00210: val_acc did not improve from 0.82475
# Epoch 211/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4323 - acc: 0.8462 - val_loss: 0.4146 - val_acc: 0.8200
#
# Epoch 00211: val_acc did not improve from 0.82475
# Epoch 212/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4386 - acc: 0.8504 - val_loss: 0.4248 - val_acc: 0.8128
#
# Epoch 00212: val_acc did not improve from 0.82475
# Epoch 213/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4356 - acc: 0.8498 - val_loss: 0.4225 - val_acc: 0.8141
#
# Epoch 00213: val_acc did not improve from 0.82475
# Epoch 214/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4328 - acc: 0.8454 - val_loss: 0.4147 - val_acc: 0.8197
#
# Epoch 00214: val_acc did not improve from 0.82475
# Epoch 215/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4367 - acc: 0.8456 - val_loss: 0.4187 - val_acc: 0.8184
#
# Epoch 00215: val_acc did not improve from 0.82475
# Epoch 216/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4290 - acc: 0.8511 - val_loss: 0.4285 - val_acc: 0.8150
#
# Epoch 00216: val_acc did not improve from 0.82475
# Epoch 217/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4355 - acc: 0.8465 - val_loss: 0.4188 - val_acc: 0.8171
#
# Epoch 00217: val_acc did not improve from 0.82475
# Epoch 218/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4343 - acc: 0.8437 - val_loss: 0.4118 - val_acc: 0.8231
#
# Epoch 00218: val_acc did not improve from 0.82475
# Epoch 219/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4308 - acc: 0.8495 - val_loss: 0.4214 - val_acc: 0.8190
#
# Epoch 00219: val_acc did not improve from 0.82475
# Epoch 220/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4316 - acc: 0.8491 - val_loss: 0.4268 - val_acc: 0.8162
#
# Epoch 00220: val_acc did not improve from 0.82475
# Epoch 221/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4302 - acc: 0.8509 - val_loss: 0.4306 - val_acc: 0.8112
#
# Epoch 00221: val_acc did not improve from 0.82475
# Epoch 222/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4317 - acc: 0.8451 - val_loss: 0.4124 - val_acc: 0.8243
#
# Epoch 00222: val_acc did not improve from 0.82475
# Epoch 223/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4310 - acc: 0.8494 - val_loss: 0.4296 - val_acc: 0.8112
#
# Epoch 00223: val_acc did not improve from 0.82475
# Epoch 224/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4346 - acc: 0.8483 - val_loss: 0.4238 - val_acc: 0.8157
#
# Epoch 00224: val_acc did not improve from 0.82475
# Epoch 225/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4302 - acc: 0.8489 - val_loss: 0.4243 - val_acc: 0.8163
#
# Epoch 00225: val_acc did not improve from 0.82475
# Epoch 226/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4302 - acc: 0.8485 - val_loss: 0.4178 - val_acc: 0.8224
#
# Epoch 00226: val_acc did not improve from 0.82475
# Epoch 227/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4326 - acc: 0.8481 - val_loss: 0.4211 - val_acc: 0.8206
#
# Epoch 00227: val_acc did not improve from 0.82475
# Epoch 228/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4364 - acc: 0.8489 - val_loss: 0.4257 - val_acc: 0.8135
#
# Epoch 00228: val_acc did not improve from 0.82475
# Epoch 229/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4335 - acc: 0.8507 - val_loss: 0.4355 - val_acc: 0.8067
#
# Epoch 00229: val_acc did not improve from 0.82475
# Epoch 230/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4324 - acc: 0.8488 - val_loss: 0.4218 - val_acc: 0.8161
#
# Epoch 00230: val_acc did not improve from 0.82475
# Epoch 231/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4297 - acc: 0.8492 - val_loss: 0.4210 - val_acc: 0.8217
#
# Epoch 00231: val_acc did not improve from 0.82475
# Epoch 232/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4293 - acc: 0.8510 - val_loss: 0.4302 - val_acc: 0.8118
#
# Epoch 00232: val_acc did not improve from 0.82475
# Epoch 233/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4305 - acc: 0.8507 - val_loss: 0.4233 - val_acc: 0.8149
#
# Epoch 00233: val_acc did not improve from 0.82475
# Epoch 234/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4296 - acc: 0.8464 - val_loss: 0.4230 - val_acc: 0.8206
#
# Epoch 00234: val_acc did not improve from 0.82475
# Epoch 235/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4270 - acc: 0.8529 - val_loss: 0.4331 - val_acc: 0.8150
#
# Epoch 00235: val_acc did not improve from 0.82475
# Epoch 236/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4281 - acc: 0.8499 - val_loss: 0.4235 - val_acc: 0.8192
#
# Epoch 00236: val_acc did not improve from 0.82475
# Epoch 237/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4310 - acc: 0.8470 - val_loss: 0.4223 - val_acc: 0.8208
#
# Epoch 00237: val_acc did not improve from 0.82475
# Epoch 238/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4306 - acc: 0.8532 - val_loss: 0.4307 - val_acc: 0.8133
#
# Epoch 00238: val_acc did not improve from 0.82475
# Epoch 239/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4299 - acc: 0.8507 - val_loss: 0.4331 - val_acc: 0.8138
#
# Epoch 00239: val_acc did not improve from 0.82475
# Epoch 240/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4274 - acc: 0.8470 - val_loss: 0.4240 - val_acc: 0.8197
#
# Epoch 00240: val_acc did not improve from 0.82475
# Epoch 241/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4288 - acc: 0.8455 - val_loss: 0.4217 - val_acc: 0.8173
#
# Epoch 00241: val_acc did not improve from 0.82475
# Epoch 242/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4299 - acc: 0.8495 - val_loss: 0.4298 - val_acc: 0.8165
#
# Epoch 00242: val_acc did not improve from 0.82475
# Epoch 243/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4259 - acc: 0.8482 - val_loss: 0.4259 - val_acc: 0.8165
#
# Epoch 00243: val_acc did not improve from 0.82475
# Epoch 244/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4258 - acc: 0.8481 - val_loss: 0.4237 - val_acc: 0.8229
#
# Epoch 00244: val_acc did not improve from 0.82475
# Epoch 245/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4281 - acc: 0.8510 - val_loss: 0.4255 - val_acc: 0.8174
#
# Epoch 00245: val_acc did not improve from 0.82475
# Epoch 246/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4283 - acc: 0.8506 - val_loss: 0.4300 - val_acc: 0.8137
#
# Epoch 00246: val_acc did not improve from 0.82475
# Epoch 247/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4272 - acc: 0.8492 - val_loss: 0.4220 - val_acc: 0.8199
#
# Epoch 00247: val_acc did not improve from 0.82475
# Epoch 248/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4248 - acc: 0.8501 - val_loss: 0.4298 - val_acc: 0.8179
#
# Epoch 00248: val_acc did not improve from 0.82475
# Epoch 249/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4211 - acc: 0.8534 - val_loss: 0.4290 - val_acc: 0.8170
#
# Epoch 00249: val_acc did not improve from 0.82475
# Epoch 250/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4304 - acc: 0.8481 - val_loss: 0.4260 - val_acc: 0.8176
#
# Epoch 00250: val_acc did not improve from 0.82475
# Epoch 251/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4224 - acc: 0.8540 - val_loss: 0.4308 - val_acc: 0.8175
#
# Epoch 00251: val_acc did not improve from 0.82475
# Epoch 252/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4249 - acc: 0.8501 - val_loss: 0.4221 - val_acc: 0.8232
#
# Epoch 00252: val_acc did not improve from 0.82475
# Epoch 253/300
# 32561/32561 [==============================] - 1s 22us/step - loss: 0.4247 - acc: 0.8542 - val_loss: 0.4346 - val_acc: 0.8142
#
# Epoch 00253: val_acc did not improve from 0.82475
# Epoch 254/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.4244 - acc: 0.8542 - val_loss: 0.4369 - val_acc: 0.8130
#
# Epoch 00254: val_acc did not improve from 0.82475
# Epoch 255/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4245 - acc: 0.8479 - val_loss: 0.4249 - val_acc: 0.8205
#
# Epoch 00255: val_acc did not improve from 0.82475
# Epoch 256/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4276 - acc: 0.8469 - val_loss: 0.4280 - val_acc: 0.8182
#
# Epoch 00256: val_acc did not improve from 0.82475
# Epoch 257/300
# 32561/32561 [==============================] - 1s 21us/step - loss: 0.4264 - acc: 0.8549 - val_loss: 0.4424 - val_acc: 0.8096
#
# Epoch 00257: val_acc did not improve from 0.82475
# Epoch 258/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4264 - acc: 0.8480 - val_loss: 0.4317 - val_acc: 0.8139
#
# Epoch 00258: val_acc did not improve from 0.82475
# Epoch 259/300
# 32561/32561 [==============================] - 1s 30us/step - loss: 0.4275 - acc: 0.8478 - val_loss: 0.4219 - val_acc: 0.8244
#
# Epoch 00259: val_acc did not improve from 0.82475
# Epoch 260/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4230 - acc: 0.8514 - val_loss: 0.4355 - val_acc: 0.8148
#
# Epoch 00260: val_acc did not improve from 0.82475
# Epoch 261/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4223 - acc: 0.8522 - val_loss: 0.4381 - val_acc: 0.8119
#
# Epoch 00261: val_acc did not improve from 0.82475
# Epoch 262/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4182 - acc: 0.8542 - val_loss: 0.4292 - val_acc: 0.8218
#
# Epoch 00262: val_acc did not improve from 0.82475
# Epoch 263/300
# 32561/32561 [==============================] - 1s 37us/step - loss: 0.4262 - acc: 0.8464 - val_loss: 0.4245 - val_acc: 0.8201
#
# Epoch 00263: val_acc did not improve from 0.82475
# Epoch 264/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4210 - acc: 0.8531 - val_loss: 0.4398 - val_acc: 0.8145
#
# Epoch 00264: val_acc did not improve from 0.82475
# Epoch 265/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4245 - acc: 0.8534 - val_loss: 0.4345 - val_acc: 0.8150
#
# Epoch 00265: val_acc did not improve from 0.82475
# Epoch 266/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.4233 - acc: 0.8483 - val_loss: 0.4285 - val_acc: 0.8194
#
# Epoch 00266: val_acc did not improve from 0.82475
# Epoch 267/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4242 - acc: 0.8517 - val_loss: 0.4312 - val_acc: 0.8176
#
# Epoch 00267: val_acc did not improve from 0.82475
# Epoch 268/300
# 32561/32561 [==============================] - 1s 27us/step - loss: 0.4249 - acc: 0.8530 - val_loss: 0.4359 - val_acc: 0.8141
#
# Epoch 00268: val_acc did not improve from 0.82475
# Epoch 269/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4190 - acc: 0.8519 - val_loss: 0.4284 - val_acc: 0.8211
#
# Epoch 00269: val_acc did not improve from 0.82475
# Epoch 270/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4222 - acc: 0.8504 - val_loss: 0.4336 - val_acc: 0.8189
#
# Epoch 00270: val_acc did not improve from 0.82475
# Epoch 271/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4174 - acc: 0.8511 - val_loss: 0.4307 - val_acc: 0.8186
#
# Epoch 00271: val_acc did not improve from 0.82475
# Epoch 272/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4225 - acc: 0.8523 - val_loss: 0.4379 - val_acc: 0.8163
#
# Epoch 00272: val_acc did not improve from 0.82475
# Epoch 273/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4213 - acc: 0.8540 - val_loss: 0.4377 - val_acc: 0.8140
#
# Epoch 00273: val_acc did not improve from 0.82475
# Epoch 274/300
# 32561/32561 [==============================] - 1s 33us/step - loss: 0.4171 - acc: 0.8519 - val_loss: 0.4307 - val_acc: 0.8229
#
# Epoch 00274: val_acc did not improve from 0.82475
# Epoch 275/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4259 - acc: 0.8496 - val_loss: 0.4397 - val_acc: 0.8124
#
# Epoch 00275: val_acc did not improve from 0.82475
# Epoch 276/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4205 - acc: 0.8552 - val_loss: 0.4333 - val_acc: 0.8166
#
# Epoch 00276: val_acc did not improve from 0.82475
# Epoch 277/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4201 - acc: 0.8506 - val_loss: 0.4354 - val_acc: 0.8171
#
# Epoch 00277: val_acc did not improve from 0.82475
# Epoch 278/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4173 - acc: 0.8527 - val_loss: 0.4405 - val_acc: 0.8158
#
# Epoch 00278: val_acc did not improve from 0.82475
# Epoch 279/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4181 - acc: 0.8513 - val_loss: 0.4357 - val_acc: 0.8155
#
# Epoch 00279: val_acc did not improve from 0.82475
# Epoch 280/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4192 - acc: 0.8531 - val_loss: 0.4441 - val_acc: 0.8120
#
# Epoch 00280: val_acc did not improve from 0.82475
# Epoch 281/300
# 32561/32561 [==============================] - 1s 26us/step - loss: 0.4205 - acc: 0.8505 - val_loss: 0.4313 - val_acc: 0.8179
#
# Epoch 00281: val_acc did not improve from 0.82475
# Epoch 282/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4182 - acc: 0.8513 - val_loss: 0.4366 - val_acc: 0.8155
#
# Epoch 00282: val_acc did not improve from 0.82475
# Epoch 283/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4165 - acc: 0.8547 - val_loss: 0.4450 - val_acc: 0.8125
#
# Epoch 00283: val_acc did not improve from 0.82475
# Epoch 284/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4186 - acc: 0.8526 - val_loss: 0.4371 - val_acc: 0.8186
#
# Epoch 00284: val_acc did not improve from 0.82475
# Epoch 285/300
# 32561/32561 [==============================] - 1s 24us/step - loss: 0.4192 - acc: 0.8514 - val_loss: 0.4310 - val_acc: 0.8197
#
# Epoch 00285: val_acc did not improve from 0.82475
# Epoch 286/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4157 - acc: 0.8565 - val_loss: 0.4377 - val_acc: 0.8145
#
# Epoch 00286: val_acc did not improve from 0.82475
# Epoch 287/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4201 - acc: 0.8523 - val_loss: 0.4361 - val_acc: 0.8167
#
# Epoch 00287: val_acc did not improve from 0.82475
# Epoch 288/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.4185 - acc: 0.8548 - val_loss: 0.4433 - val_acc: 0.8122
#
# Epoch 00288: val_acc did not improve from 0.82475
# Epoch 289/300
# 32561/32561 [==============================] - 1s 34us/step - loss: 0.4189 - acc: 0.8534 - val_loss: 0.4313 - val_acc: 0.8183
#
# Epoch 00289: val_acc did not improve from 0.82475
# Epoch 290/300
# 32561/32561 [==============================] - 1s 29us/step - loss: 0.4154 - acc: 0.8530 - val_loss: 0.4374 - val_acc: 0.8195
#
# Epoch 00290: val_acc did not improve from 0.82475
# Epoch 291/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4180 - acc: 0.8549 - val_loss: 0.4438 - val_acc: 0.8139
#
# Epoch 00291: val_acc did not improve from 0.82475
# Epoch 292/300
# 32561/32561 [==============================] - 1s 31us/step - loss: 0.4174 - acc: 0.8540 - val_loss: 0.4416 - val_acc: 0.8140
#
# Epoch 00292: val_acc did not improve from 0.82475
# Epoch 293/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4160 - acc: 0.8507 - val_loss: 0.4367 - val_acc: 0.8192
#
# Epoch 00293: val_acc did not improve from 0.82475
# Epoch 294/300
# 32561/32561 [==============================] - 1s 32us/step - loss: 0.4166 - acc: 0.8521 - val_loss: 0.4392 - val_acc: 0.8174
#
# Epoch 00294: val_acc did not improve from 0.82475
# Epoch 295/300
# 32561/32561 [==============================] - 1s 36us/step - loss: 0.4190 - acc: 0.8536 - val_loss: 0.4449 - val_acc: 0.8112
#
# Epoch 00295: val_acc did not improve from 0.82475
# Epoch 296/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4177 - acc: 0.8502 - val_loss: 0.4367 - val_acc: 0.8161
#
# Epoch 00296: val_acc did not improve from 0.82475
# Epoch 297/300
# 32561/32561 [==============================] - 1s 35us/step - loss: 0.4193 - acc: 0.8521 - val_loss: 0.4416 - val_acc: 0.8154
#
# Epoch 00297: val_acc did not improve from 0.82475
# Epoch 298/300
# 32561/32561 [==============================] - 1s 28us/step - loss: 0.4114 - acc: 0.8554 - val_loss: 0.4395 - val_acc: 0.8184
#
# Epoch 00298: val_acc did not improve from 0.82475
# Epoch 299/300
# 32561/32561 [==============================] - 1s 25us/step - loss: 0.4164 - acc: 0.8559 - val_loss: 0.4487 - val_acc: 0.8104
#
# Epoch 00299: val_acc did not improve from 0.82475
# Epoch 300/300
# 32561/32561 [==============================] - 1s 23us/step - loss: 0.4145 - acc: 0.8526 - val_loss: 0.4406 - val_acc: 0.8181
#
# Epoch 00300: val_acc did not improve from 0.82475
# Precision: Salaries below 50K 1.0 2
# Precision: Salaries higher than 50K 1.0 2
